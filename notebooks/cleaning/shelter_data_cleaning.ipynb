# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../'))
sys.path.insert(1, module_path + "/utils")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re 
pd.options.mode.chained_assignment = None 
from data_processing import check_concatenation, preprocess_climate_data, preprocess_climate_data, df_equality

pd.set_option('display.max_columns', None)

# %% [markdown]
# #### data retrieval

# %%
# save all url's
url_2021 = '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2021.csv'
url_2022 = '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2022.csv'
url_2023 = '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2023.csv'
url_2024 = '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-Q1:2024.csv'

# read into df
df_2021 = pd.read_csv(url_2021, index_col=False)
df_2022 = pd.read_csv(url_2022, index_col=False)
df_2023 = pd.read_csv(url_2023, index_col=False)
df_2024 = pd.read_csv(url_2024, index_col=False)

# Concatenate all DataFrames into one
shelter_df = pd.concat([df_2021, df_2022, df_2023, df_2024], ignore_index=True)
shelter_df.rename(columns=lambda x: x.strip().replace(" ", "_").lower(), inplace=True)
shelter_df.rename(columns={'occupancy_date': 'date'}, inplace=True)
display(shelter_df['date'].dtype)

shelter_df.columns
# Out:
# dtype('O')
# Index(['_id', 'date', 'organization_id', 'organization_name', 'shelter_id',
#        'shelter_group', 'location_id', 'location_name', 'location_address',
#        'location_postal_code', 'location_city', 'location_province',
#        'program_id', 'program_name', 'sector', 'program_model',
#        'overnight_service_type', 'program_area', 'service_user_count',
#        'capacity_type', 'capacity_actual_bed', 'capacity_funding_bed',
#        'occupied_beds', 'unoccupied_beds', 'unavailable_beds',
#        'capacity_actual_room', 'capacity_funding_room', 'occupied_rooms',
#        'unoccupied_rooms', 'unavailable_rooms', 'occupancy_rate_beds',
#        'occupancy_rate_rooms'],
#       dtype='object')

# %%
if check_concatenation([df_2021, df_2022, df_2023, df_2024], shelter_df):
    print("Concatenation successful!")
else:
    print("Concatenation failed!")
# Out:
# Concatenation successful!

# %%
shelter_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### fix dates, same format as climate.csv

# %% [markdown]
# > - we have date like: 21-01-10 and for 2023 like: 2023-01-01T00:00:00

# %%
pattern1 = '(\d{2})-(\d{2})-(\d{2})'
pattern2 = '(\d{4})-(\d{2})-(\d{2})'
shelter_df['date'] = shelter_df['date'].astype(str)
# Extract year, month, and day components using regex
shelter_df[['year', 'month', 'day']] = shelter_df['date'].str.extract(pattern1).fillna(shelter_df['date'].str.extract(pattern2))
# Convert extracted components to integers
shelter_df['date'] = shelter_df['day'].astype(str) + '.' + shelter_df['month'].astype(str) + '.' + shelter_df['year'].astype(str)
shelter_df.drop(columns=['year', 'month', 'day'], inplace=True)
shelter_df
# Out:
#           _id      date  organization_id         organization_name  \
# 0           1  01.01.21               24  COSTI Immigrant Services
# 1           2  01.01.21               24  COSTI Immigrant Services
# 2           3  01.01.21               24  COSTI Immigrant Services
# 3           4  01.01.21               24  COSTI Immigrant Services
# 4           5  01.01.21               24  COSTI Immigrant Services
# ...       ...       ...              ...                       ...
# 161038  12272  31.03.24               17              YWCA Toronto
# 161039  12273  31.03.24               31     Youth Without Shelter
# 161040  12274  31.03.24               31     Youth Without Shelter
# 161041  12275  31.03.24               38                 YouthLink
# 161042  12276  31.03.24               38                 YouthLink
#
#         shelter_id           shelter_group  location_id  \
# 0               40  COSTI Reception Centre       1103.0
# 1               40  COSTI Reception Centre       1103.0
# 2               40  COSTI Reception Centre       1103.0
# 3               40  COSTI Reception Centre       1103.0
# 4               40  COSTI Reception Centre       1103.0
# ...            ...                     ...          ...
# 161038          78      YWCA-348 Davenport       1129.0
# 161039          52   Youth Without Shelter       1064.0
# 161040          52   Youth Without Shelter       1064.0
# 161041          81       YouthLink Shelter       1147.0
# 161042          81       YouthLink Shelter       1147.0
#
#                                    location_name    location_address  \
# 0       COSTI/City North York West Hotel Program     1677 Wilson Ave
# 1       COSTI/City North York West Hotel Program     1677 Wilson Ave
# 2       COSTI/City North York West Hotel Program     1677 Wilson Ave
# 3       COSTI/City North York West Hotel Program     1677 Wilson Ave
# 4       COSTI/City North York West Hotel Program     1677 Wilson Ave
# ...                                          ...                 ...
# 161038                    YWCA Davenport Shelter  348 Davenport Road
# 161039                    Youth Without Shelter      6 Warrendale Ct
# 161040                    Youth Without Shelter      6 Warrendale Ct
# 161041                                YouthLink       747 Warden Ave
# 161042                                YouthLink       747 Warden Ave
#
#        location_postal_code location_city location_province  program_id  \
# 0                   M3L 1A5   North York                 ON       15371
# 1                   M3L 1A5   North York                 ON       16211
# 2                   M3L 1A5   North York                 ON       16192
# 3                   M3L 1A5   North York                 ON       16191
# 4                   M3L 1A5   North York                 ON       16193
# ...                     ...           ...               ...         ...
# 161038              M5R 1K6       Toronto                ON       14671
# 161039              M9V 1P9     Etobicoke                ON       12292
# 161040              M9V 1P9     Etobicoke                ON       12291
# 161041              M1L 4A1   Scarborough                ON       14891
# 161042              M1L 4A1   Scarborough                ON       14911
#
#                                              program_name       sector  \
# 0            COSTI North York West Hotel - Family Program     Families
# 1           COSTI North York West Hotel - Seniors Program  Mixed Adult
# 2               COSTI North York West Hotel Program - Men          Men
# 3       COSTI North York West Hotel Program - Mixed Adult  Mixed Adult
# 4             COSTI North York West Hotel Program - Women        Women
# ...                                                   ...          ...
# 161038                             YWCA Davenport - Youth        Youth
# 161039    Youth without Shelter Emergency Shelter Program        Youth
# 161040       Youth without Shelter Stay In School Program        Youth
# 161041                        YouthLink Emergency Program        Youth
# 161042                     YouthLink Transitional Program        Youth
#
#        program_model overnight_service_type  \
# 0          Emergency    Motel/Hotel Shelter
# 1          Emergency    Motel/Hotel Shelter
# 2          Emergency    Motel/Hotel Shelter
# 3          Emergency    Motel/Hotel Shelter
# 4          Emergency    Motel/Hotel Shelter
# ...              ...                    ...
# 161038     Emergency                Shelter
# 161039     Emergency                Shelter
# 161040  Transitional                Shelter
# 161041     Emergency                Shelter
# 161042  Transitional                Shelter
#
#                                       program_area  service_user_count  \
# 0                                COVID-19 Response                  74
# 1                                COVID-19 Response                   3
# 2                                COVID-19 Response                  24
# 3                                COVID-19 Response                  25
# 4                                COVID-19 Response                  13
# ...                                            ...                 ...
# 161038  Base Shelter and Overnight Services System                  27
# 161039  Base Shelter and Overnight Services System                  33
# 161040  Base Shelter and Overnight Services System                  20
# 161041  Base Shelter and Overnight Services System                  10
# 161042  Base Shelter and Overnight Services System                  36
#
#               capacity_type  capacity_actual_bed  capacity_funding_bed  \
# 0       Room Based Capacity                  NaN                   NaN
# 1       Room Based Capacity                  NaN                   NaN
# 2       Room Based Capacity                  NaN                   NaN
# 3       Room Based Capacity                  NaN                   NaN
# 4       Room Based Capacity                  NaN                   NaN
# ...                     ...                  ...                   ...
# 161038   Bed Based Capacity                 27.0                  27.0
# 161039   Bed Based Capacity                 33.0                  33.0
# 161040   Bed Based Capacity                 20.0                  20.0
# 161041   Bed Based Capacity                 10.0                  10.0
# 161042   Bed Based Capacity                 41.0                  41.0
#
#         occupied_beds  unoccupied_beds  unavailable_beds  \
# 0                 NaN              NaN               NaN
# 1                 NaN              NaN               NaN
# 2                 NaN              NaN               NaN
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 161038           27.0              0.0               0.0
# 161039           33.0              0.0               0.0
# 161040           20.0              0.0               0.0
# 161041           10.0              0.0               0.0
# 161042           36.0              5.0               0.0
#
#         capacity_actual_room  capacity_funding_room  occupied_rooms  \
# 0                       29.0                   58.0            26.0
# 1                        3.0                    0.0             3.0
# 2                       28.0                    0.0            23.0
# 3                       17.0                    0.0            17.0
# 4                       14.0                    0.0            13.0
# ...                      ...                    ...             ...
# 161038                   NaN                    NaN             NaN
# 161039                   NaN                    NaN             NaN
# 161040                   NaN                    NaN             NaN
# 161041                   NaN                    NaN             NaN
# 161042                   NaN                    NaN             NaN
#
#         unoccupied_rooms  unavailable_rooms  occupancy_rate_beds  \
# 0                    3.0               29.0                  NaN
# 1                    0.0                0.0                  NaN
# 2                    5.0                0.0                  NaN
# 3                    0.0                0.0                  NaN
# 4                    1.0                0.0                  NaN
# ...                  ...                ...                  ...
# 161038               NaN                NaN                100.0
# 161039               NaN                NaN                100.0
# 161040               NaN                NaN                100.0
# 161041               NaN                NaN                100.0
# 161042               NaN                NaN                 87.8
#
#         occupancy_rate_rooms
# 0                      89.66
# 1                     100.00
# 2                      82.14
# 3                     100.00
# 4                      92.86
# ...                      ...
# 161038                   NaN
# 161039                   NaN
# 161040                   NaN
# 161041                   NaN
# 161042                   NaN
#
# [161043 rows x 32 columns]

# %% [markdown]
# #### filtering data before removing columns

# %% [markdown]
# ##### --> program_type
# > there is emergency and transitional shelters, we're looking at emergency (the one's that fill up daily)

# %%
display(shelter_df['program_model'].unique())
display(shelter_df['program_model'].value_counts())
# Out:
# array(['Emergency', 'Transitional', nan], dtype=object)
# program_model
# Emergency       131341
# Transitional     29700
# Name: count, dtype: int64

# %%
# retrieve only emergency shelters
shelter_df = shelter_df[shelter_df['program_model'] == 'Emergency']

# %%
display(shelter_df['overnight_service_type'].unique())
display(shelter_df['overnight_service_type'].value_counts())
# Out:
# array(['Motel/Hotel Shelter', 'Shelter', 'Interim Housing',
#        'Isolation/Recovery Site', '24-Hour Respite Site',
#        'Warming Centre', "24-Hour Women's Drop-in",
#        'Alternative Space Protocol', 'Top Bunk Contingency Space'],
#       dtype=object)
# overnight_service_type
# Shelter                       73109
# Motel/Hotel Shelter           42250
# 24-Hour Respite Site           9864
# 24-Hour Women's Drop-in        2070
# Isolation/Recovery Site        1790
# Warming Centre                 1056
# Interim Housing                 720
# Alternative Space Protocol      388
# Top Bunk Contingency Space       94
# Name: count, dtype: int64

# %% [markdown]
# > remove rows were value in drop_values --> these are not explicitly emergency shelter, daily basis

# %%
drop_values = ['Interim Housing', 'Alternative Space Protocol', 'Top Bunk Contingency Space', 'Isolation/Recovery Site']
shelter_df = shelter_df[~shelter_df['overnight_service_type'].isin(drop_values)]

# %%
display(shelter_df['overnight_service_type'].unique())
display(shelter_df['overnight_service_type'].value_counts())
# Out:
# array(['Motel/Hotel Shelter', 'Shelter', '24-Hour Respite Site',
#        'Warming Centre', "24-Hour Women's Drop-in"], dtype=object)
# overnight_service_type
# Shelter                    73109
# Motel/Hotel Shelter        42250
# 24-Hour Respite Site        9864
# 24-Hour Women's Drop-in     2070
# Warming Centre              1056
# Name: count, dtype: int64

# %% [markdown]
# ##### check columns that are empty/nan + basic structure
# > - cross checked with the meaning of the columns in [Data Processing](../../data/Data_Processing.md)

# %%
shelter_df.isna().sum()
# Out:
# _id                           0
# date                          0
# organization_id               0
# organization_name             0
# shelter_id                    0
# shelter_group               216
# location_id                 360
# location_name              1129
# location_address           3012
# location_postal_code       3012
# location_city              3046
# location_province          3046
# program_id                    0
# program_name                 33
# sector                        0
# program_model                 0
# overnight_service_type        0
# program_area                  0
# service_user_count            0
# capacity_type                 0
# capacity_actual_bed       49135
# capacity_funding_bed      49135
# occupied_beds             49135
# unoccupied_beds           49135
# unavailable_beds          49135
# capacity_actual_room      79214
# capacity_funding_room     79253
# occupied_rooms            79214
# unoccupied_rooms          79214
# unavailable_rooms         79253
# occupancy_rate_beds       49135
# occupancy_rate_rooms      79214
# dtype: int64

# %% [markdown]
# #### look into location_id -- we need that value: missing values location# 4836

# %%
shelter_df[shelter_df['location_city'].isna()].head(10)
# Out:
#      _id      date  organization_id     organization_name  shelter_id  \
# 43    44  01.01.21                1       City of Toronto           3
# 69    70  01.01.21               26    Fred Victor Centre          42
# 128  129  01.01.21               16  Women's Hostels Inc.          27
# 184  185  02.01.21                1       City of Toronto           3
# 210  211  02.01.21               26    Fred Victor Centre          42
# 269  270  02.01.21               16  Women's Hostels Inc.          27
# 325  326  03.01.21                1       City of Toronto           3
# 351  352  03.01.21               26    Fred Victor Centre          42
# 410  411  03.01.21               16  Women's Hostels Inc.          27
# 466  467  04.01.21                1       City of Toronto           3
#
#                   shelter_group  location_id             location_name  \
# 43                 Seaton House          NaN                       NaN
# 69   Fred Victor Women's Hostel          NaN                       NaN
# 128                    Nellie's       1035.0  Nellie's Women's Shelter
# 184                Seaton House          NaN                       NaN
# 210  Fred Victor Women's Hostel          NaN                       NaN
# 269                    Nellie's       1035.0  Nellie's Women's Shelter
# 325                Seaton House          NaN                       NaN
# 351  Fred Victor Women's Hostel          NaN                       NaN
# 410                    Nellie's       1035.0  Nellie's Women's Shelter
# 466                Seaton House          NaN                       NaN
#
#     location_address location_postal_code location_city location_province  \
# 43               NaN                  NaN           NaN               NaN
# 69               NaN                  NaN           NaN               NaN
# 128              NaN                  NaN           NaN               NaN
# 184              NaN                  NaN           NaN               NaN
# 210              NaN                  NaN           NaN               NaN
# 269              NaN                  NaN           NaN               NaN
# 325              NaN                  NaN           NaN               NaN
# 351              NaN                  NaN           NaN               NaN
# 410              NaN                  NaN           NaN               NaN
# 466              NaN                  NaN           NaN               NaN
#
#      program_id                          program_name sector program_model  \
# 43        15751  Seaton House Hostel Response Program    Men     Emergency
# 69        12256    Fred Victor Women's Hostel Program  Women     Emergency
# 128       12051              Nellie's Women's Shelter  Women     Emergency
# 184       15751  Seaton House Hostel Response Program    Men     Emergency
# 210       12256    Fred Victor Women's Hostel Program  Women     Emergency
# 269       12051              Nellie's Women's Shelter  Women     Emergency
# 325       15751  Seaton House Hostel Response Program    Men     Emergency
# 351       12256    Fred Victor Women's Hostel Program  Women     Emergency
# 410       12051              Nellie's Women's Shelter  Women     Emergency
# 466       15751  Seaton House Hostel Response Program    Men     Emergency
#
#     overnight_service_type                                program_area  \
# 43                 Shelter                           COVID-19 Response
# 69                 Shelter  Base Shelter and Overnight Services System
# 128                Shelter  Base Shelter and Overnight Services System
# 184                Shelter                           COVID-19 Response
# 210                Shelter  Base Shelter and Overnight Services System
# 269                Shelter  Base Shelter and Overnight Services System
# 325                Shelter                           COVID-19 Response
# 351                Shelter  Base Shelter and Overnight Services System
# 410                Shelter  Base Shelter and Overnight Services System
# 466                Shelter                           COVID-19 Response
#
#      service_user_count       capacity_type  capacity_actual_bed  \
# 43                   55  Bed Based Capacity                 55.0
# 69                   25  Bed Based Capacity                 25.0
# 128                  10  Bed Based Capacity                 10.0
# 184                  54  Bed Based Capacity                 55.0
# 210                  25  Bed Based Capacity                 25.0
# 269                  10  Bed Based Capacity                 10.0
# 325                  54  Bed Based Capacity                 55.0
# 351                  25  Bed Based Capacity                 25.0
# 410                  10  Bed Based Capacity                 10.0
# 466                  52  Bed Based Capacity                 55.0
#
#      capacity_funding_bed  occupied_beds  unoccupied_beds  unavailable_beds  \
# 43                   55.0           55.0              0.0               0.0
# 69                   25.0           25.0              0.0               0.0
# 128                  10.0           10.0              0.0               0.0
# 184                  55.0           54.0              1.0               0.0
# 210                  25.0           25.0              0.0               0.0
# 269                  10.0           10.0              0.0               0.0
# 325                  55.0           54.0              1.0               0.0
# 351                  25.0           25.0              0.0               0.0
# 410                  10.0           10.0              0.0               0.0
# 466                  55.0           52.0              3.0               0.0
#
#      capacity_actual_room  capacity_funding_room  occupied_rooms  \
# 43                    NaN                    NaN             NaN
# 69                    NaN                    NaN             NaN
# 128                   NaN                    NaN             NaN
# 184                   NaN                    NaN             NaN
# 210                   NaN                    NaN             NaN
# 269                   NaN                    NaN             NaN
# 325                   NaN                    NaN             NaN
# 351                   NaN                    NaN             NaN
# 410                   NaN                    NaN             NaN
# 466                   NaN                    NaN             NaN
#
#      unoccupied_rooms  unavailable_rooms  occupancy_rate_beds  \
# 43                NaN                NaN               100.00
# 69                NaN                NaN               100.00
# 128               NaN                NaN               100.00
# 184               NaN                NaN                98.18
# 210               NaN                NaN               100.00
# 269               NaN                NaN               100.00
# 325               NaN                NaN                98.18
# 351               NaN                NaN               100.00
# 410               NaN                NaN               100.00
# 466               NaN                NaN                94.55
#
#      occupancy_rate_rooms
# 43                    NaN
# 69                    NaN
# 128                   NaN
# 184                   NaN
# 210                   NaN
# 269                   NaN
# 325                   NaN
# 351                   NaN
# 410                   NaN
# 466                   NaN

# %%
# check if we can derive the information from shelter_id
shelter_df[shelter_df['shelter_id'] == 82]
# Out:
#           _id      date  organization_id organization_name  shelter_id  \
# 26910   26911  09.07.21                1   City of Toronto          82
# 27051   27052  10.07.21                1   City of Toronto          82
# 27191   27192  11.07.21                1   City of Toronto          82
# 27330   27331  12.07.21                1   City of Toronto          82
# 27470   27471  13.07.21                1   City of Toronto          82
# ...       ...       ...              ...               ...         ...
# 160663  11897  29.03.24                1   City of Toronto          82
# 160798  12032  30.03.24                1   City of Toronto          82
# 160799  12033  30.03.24                1   City of Toronto          82
# 160934  12168  31.03.24                1   City of Toronto          82
# 160935  12169  31.03.24                1   City of Toronto          82
#
#                        shelter_group  location_id  \
# 26910   SSHA Etobicoke Hotel Program       1163.0
# 27051   SSHA Etobicoke Hotel Program       1163.0
# 27191   SSHA Etobicoke Hotel Program       1163.0
# 27330   SSHA Etobicoke Hotel Program       1163.0
# 27470   SSHA Etobicoke Hotel Program       1163.0
# ...                              ...          ...
# 160663  SSHA Etobicoke Hotel Program       1163.0
# 160798  SSHA Etobicoke Hotel Program       1561.0
# 160799  SSHA Etobicoke Hotel Program       1163.0
# 160934  SSHA Etobicoke Hotel Program       1561.0
# 160935  SSHA Etobicoke Hotel Program       1163.0
#
#                          location_name                location_address  \
# 26910     SSHA Etobicoke Hotel Program                             NaN
# 27051     SSHA Etobicoke Hotel Program                             NaN
# 27191     SSHA Etobicoke Hotel Program                             NaN
# 27330     SSHA Etobicoke Hotel Program                             NaN
# 27470     SSHA Etobicoke Hotel Program                             NaN
# ...                                ...                             ...
# 160663    SSHA Etobicoke Hotel Program                             NaN
# 160798  885 Scarborough Golf Club Road  885 Scarborough Golf Club Road
# 160799    SSHA Etobicoke Hotel Program                             NaN
# 160934  885 Scarborough Golf Club Road  885 Scarborough Golf Club Road
# 160935    SSHA Etobicoke Hotel Program                             NaN
#
#        location_postal_code location_city location_province  program_id  \
# 26910                   NaN           NaN               NaN       16551
# 27051                   NaN           NaN               NaN       16551
# 27191                   NaN           NaN               NaN       16551
# 27330                   NaN           NaN               NaN       16551
# 27470                   NaN           NaN               NaN       16551
# ...                     ...           ...               ...         ...
# 160663                  NaN           NaN               NaN       16551
# 160798              M1G 1J6       Toronto                ON       17931
# 160799                  NaN           NaN               NaN       16551
# 160934              M1G 1J6       Toronto                ON       17931
# 160935                  NaN           NaN               NaN       16551
#
#                                              program_name       sector  \
# 26910                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27051                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27191                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27330                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27470                        SSHA Etobicoke Hotel Program  Mixed Adult
# ...                                                   ...          ...
# 160663                       SSHA Etobicoke Hotel Program  Mixed Adult
# 160798  SSHA - Warming Centre - Scarborough Golf Club ...  Mixed Adult
# 160799                       SSHA Etobicoke Hotel Program  Mixed Adult
# 160934  SSHA - Warming Centre - Scarborough Golf Club ...  Mixed Adult
# 160935                       SSHA Etobicoke Hotel Program  Mixed Adult
#
#        program_model overnight_service_type       program_area  \
# 26910      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27051      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27191      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27330      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27470      Emergency    Motel/Hotel Shelter  COVID-19 Response
# ...              ...                    ...                ...
# 160663     Emergency    Motel/Hotel Shelter  COVID-19 Response
# 160798     Emergency         Warming Centre    Winter Programs
# 160799     Emergency    Motel/Hotel Shelter  COVID-19 Response
# 160934     Emergency         Warming Centre    Winter Programs
# 160935     Emergency    Motel/Hotel Shelter  COVID-19 Response
#
#         service_user_count        capacity_type  capacity_actual_bed  \
# 26910                    2   Bed Based Capacity                 88.0
# 27051                    2   Bed Based Capacity                 88.0
# 27191                    3   Bed Based Capacity                 88.0
# 27330                    3   Bed Based Capacity                 88.0
# 27470                    3   Bed Based Capacity                 88.0
# ...                    ...                  ...                  ...
# 160663                 169  Room Based Capacity                  NaN
# 160798                  45   Bed Based Capacity                 48.0
# 160799                 170  Room Based Capacity                  NaN
# 160934                  43   Bed Based Capacity                 48.0
# 160935                 170  Room Based Capacity                  NaN
#
#         capacity_funding_bed  occupied_beds  unoccupied_beds  \
# 26910                   88.0            2.0             86.0
# 27051                   88.0            2.0             86.0
# 27191                   88.0            3.0             85.0
# 27330                   88.0            3.0             85.0
# 27470                   88.0            3.0             85.0
# ...                      ...            ...              ...
# 160663                   NaN            NaN              NaN
# 160798                  48.0           45.0              3.0
# 160799                   NaN            NaN              NaN
# 160934                  48.0           43.0              5.0
# 160935                   NaN            NaN              NaN
#
#         unavailable_beds  capacity_actual_room  capacity_funding_room  \
# 26910                0.0                   NaN                    NaN
# 27051                0.0                   NaN                    NaN
# 27191                0.0                   NaN                    NaN
# 27330                0.0                   NaN                    NaN
# 27470                0.0                   NaN                    NaN
# ...                  ...                   ...                    ...
# 160663               NaN                 158.0                  134.0
# 160798               0.0                   NaN                    NaN
# 160799               NaN                 158.0                  134.0
# 160934               0.0                   NaN                    NaN
# 160935               NaN                 158.0                  134.0
#
#         occupied_rooms  unoccupied_rooms  unavailable_rooms  \
# 26910              NaN               NaN                NaN
# 27051              NaN               NaN                NaN
# 27191              NaN               NaN                NaN
# 27330              NaN               NaN                NaN
# 27470              NaN               NaN                NaN
# ...                ...               ...                ...
# 160663           157.0               1.0                0.0
# 160798             NaN               NaN                NaN
# 160799           158.0               0.0                0.0
# 160934             NaN               NaN                NaN
# 160935           158.0               0.0                0.0
#
#         occupancy_rate_beds  occupancy_rate_rooms
# 26910                  2.27                   NaN
# 27051                  2.27                   NaN
# 27191                  3.41                   NaN
# 27330                  3.41                   NaN
# 27470                  3.41                   NaN
# ...                     ...                   ...
# 160663                  NaN                 99.37
# 160798                93.75                   NaN
# 160799                  NaN                100.00
# 160934                89.58                   NaN
# 160935                  NaN                100.00
#
# [1046 rows x 32 columns]

# %% [markdown]
# ##### derive data from other entries that have everything filled

# %%
# Group by 'shelter_id' and get the first non-null value of 'location_city'
shelter_id_mapping = shelter_df.groupby('shelter_id')['location_city'].first()

# Fill missing values in 'location_city' based on 'shelter_id'
shelter_df['location_city'] = shelter_df.apply(lambda row: shelter_id_mapping.get(row['shelter_id'], row['location_city']), axis=1)

# Display the updated DataFrame
shelter_df[shelter_df['shelter_id'] == 82]
# Out:
#           _id      date  organization_id organization_name  shelter_id  \
# 26910   26911  09.07.21                1   City of Toronto          82
# 27051   27052  10.07.21                1   City of Toronto          82
# 27191   27192  11.07.21                1   City of Toronto          82
# 27330   27331  12.07.21                1   City of Toronto          82
# 27470   27471  13.07.21                1   City of Toronto          82
# ...       ...       ...              ...               ...         ...
# 160663  11897  29.03.24                1   City of Toronto          82
# 160798  12032  30.03.24                1   City of Toronto          82
# 160799  12033  30.03.24                1   City of Toronto          82
# 160934  12168  31.03.24                1   City of Toronto          82
# 160935  12169  31.03.24                1   City of Toronto          82
#
#                        shelter_group  location_id  \
# 26910   SSHA Etobicoke Hotel Program       1163.0
# 27051   SSHA Etobicoke Hotel Program       1163.0
# 27191   SSHA Etobicoke Hotel Program       1163.0
# 27330   SSHA Etobicoke Hotel Program       1163.0
# 27470   SSHA Etobicoke Hotel Program       1163.0
# ...                              ...          ...
# 160663  SSHA Etobicoke Hotel Program       1163.0
# 160798  SSHA Etobicoke Hotel Program       1561.0
# 160799  SSHA Etobicoke Hotel Program       1163.0
# 160934  SSHA Etobicoke Hotel Program       1561.0
# 160935  SSHA Etobicoke Hotel Program       1163.0
#
#                          location_name                location_address  \
# 26910     SSHA Etobicoke Hotel Program                             NaN
# 27051     SSHA Etobicoke Hotel Program                             NaN
# 27191     SSHA Etobicoke Hotel Program                             NaN
# 27330     SSHA Etobicoke Hotel Program                             NaN
# 27470     SSHA Etobicoke Hotel Program                             NaN
# ...                                ...                             ...
# 160663    SSHA Etobicoke Hotel Program                             NaN
# 160798  885 Scarborough Golf Club Road  885 Scarborough Golf Club Road
# 160799    SSHA Etobicoke Hotel Program                             NaN
# 160934  885 Scarborough Golf Club Road  885 Scarborough Golf Club Road
# 160935    SSHA Etobicoke Hotel Program                             NaN
#
#        location_postal_code location_city location_province  program_id  \
# 26910                   NaN       Toronto               NaN       16551
# 27051                   NaN       Toronto               NaN       16551
# 27191                   NaN       Toronto               NaN       16551
# 27330                   NaN       Toronto               NaN       16551
# 27470                   NaN       Toronto               NaN       16551
# ...                     ...           ...               ...         ...
# 160663                  NaN       Toronto               NaN       16551
# 160798              M1G 1J6       Toronto                ON       17931
# 160799                  NaN       Toronto               NaN       16551
# 160934              M1G 1J6       Toronto                ON       17931
# 160935                  NaN       Toronto               NaN       16551
#
#                                              program_name       sector  \
# 26910                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27051                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27191                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27330                        SSHA Etobicoke Hotel Program  Mixed Adult
# 27470                        SSHA Etobicoke Hotel Program  Mixed Adult
# ...                                                   ...          ...
# 160663                       SSHA Etobicoke Hotel Program  Mixed Adult
# 160798  SSHA - Warming Centre - Scarborough Golf Club ...  Mixed Adult
# 160799                       SSHA Etobicoke Hotel Program  Mixed Adult
# 160934  SSHA - Warming Centre - Scarborough Golf Club ...  Mixed Adult
# 160935                       SSHA Etobicoke Hotel Program  Mixed Adult
#
#        program_model overnight_service_type       program_area  \
# 26910      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27051      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27191      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27330      Emergency    Motel/Hotel Shelter  COVID-19 Response
# 27470      Emergency    Motel/Hotel Shelter  COVID-19 Response
# ...              ...                    ...                ...
# 160663     Emergency    Motel/Hotel Shelter  COVID-19 Response
# 160798     Emergency         Warming Centre    Winter Programs
# 160799     Emergency    Motel/Hotel Shelter  COVID-19 Response
# 160934     Emergency         Warming Centre    Winter Programs
# 160935     Emergency    Motel/Hotel Shelter  COVID-19 Response
#
#         service_user_count        capacity_type  capacity_actual_bed  \
# 26910                    2   Bed Based Capacity                 88.0
# 27051                    2   Bed Based Capacity                 88.0
# 27191                    3   Bed Based Capacity                 88.0
# 27330                    3   Bed Based Capacity                 88.0
# 27470                    3   Bed Based Capacity                 88.0
# ...                    ...                  ...                  ...
# 160663                 169  Room Based Capacity                  NaN
# 160798                  45   Bed Based Capacity                 48.0
# 160799                 170  Room Based Capacity                  NaN
# 160934                  43   Bed Based Capacity                 48.0
# 160935                 170  Room Based Capacity                  NaN
#
#         capacity_funding_bed  occupied_beds  unoccupied_beds  \
# 26910                   88.0            2.0             86.0
# 27051                   88.0            2.0             86.0
# 27191                   88.0            3.0             85.0
# 27330                   88.0            3.0             85.0
# 27470                   88.0            3.0             85.0
# ...                      ...            ...              ...
# 160663                   NaN            NaN              NaN
# 160798                  48.0           45.0              3.0
# 160799                   NaN            NaN              NaN
# 160934                  48.0           43.0              5.0
# 160935                   NaN            NaN              NaN
#
#         unavailable_beds  capacity_actual_room  capacity_funding_room  \
# 26910                0.0                   NaN                    NaN
# 27051                0.0                   NaN                    NaN
# 27191                0.0                   NaN                    NaN
# 27330                0.0                   NaN                    NaN
# 27470                0.0                   NaN                    NaN
# ...                  ...                   ...                    ...
# 160663               NaN                 158.0                  134.0
# 160798               0.0                   NaN                    NaN
# 160799               NaN                 158.0                  134.0
# 160934               0.0                   NaN                    NaN
# 160935               NaN                 158.0                  134.0
#
#         occupied_rooms  unoccupied_rooms  unavailable_rooms  \
# 26910              NaN               NaN                NaN
# 27051              NaN               NaN                NaN
# 27191              NaN               NaN                NaN
# 27330              NaN               NaN                NaN
# 27470              NaN               NaN                NaN
# ...                ...               ...                ...
# 160663           157.0               1.0                0.0
# 160798             NaN               NaN                NaN
# 160799           158.0               0.0                0.0
# 160934             NaN               NaN                NaN
# 160935           158.0               0.0                0.0
#
#         occupancy_rate_beds  occupancy_rate_rooms
# 26910                  2.27                   NaN
# 27051                  2.27                   NaN
# 27191                  3.41                   NaN
# 27330                  3.41                   NaN
# 27470                  3.41                   NaN
# ...                     ...                   ...
# 160663                  NaN                 99.37
# 160798                93.75                   NaN
# 160799                  NaN                100.00
# 160934                89.58                   NaN
# 160935                  NaN                100.00
#
# [1046 rows x 32 columns]

# %%
shelter_df['location_city'].isna().sum()
# Out:
# 1185

# %% [markdown]
# ##### still 1185

# %%
shelter_df[shelter_df['location_city'].isna()].head(10)
# Out:
#        _id      date  organization_id     organization_name  shelter_id  \
# 128    129  01.01.21               16  Women's Hostels Inc.          27
# 269    270  02.01.21               16  Women's Hostels Inc.          27
# 410    411  03.01.21               16  Women's Hostels Inc.          27
# 551    552  04.01.21               16  Women's Hostels Inc.          27
# 693    694  05.01.21               16  Women's Hostels Inc.          27
# 835    836  06.01.21               16  Women's Hostels Inc.          27
# 977    978  07.01.21               16  Women's Hostels Inc.          27
# 1118  1119  08.01.21               16  Women's Hostels Inc.          27
# 1259  1260  09.01.21               16  Women's Hostels Inc.          27
# 1400  1401  10.01.21               16  Women's Hostels Inc.          27
#
#      shelter_group  location_id             location_name location_address  \
# 128       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 269       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 410       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 551       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 693       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 835       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 977       Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 1118      Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 1259      Nellie's       1035.0  Nellie's Women's Shelter              NaN
# 1400      Nellie's       1035.0  Nellie's Women's Shelter              NaN
#
#      location_postal_code location_city location_province  program_id  \
# 128                   NaN          None               NaN       12051
# 269                   NaN          None               NaN       12051
# 410                   NaN          None               NaN       12051
# 551                   NaN          None               NaN       12051
# 693                   NaN          None               NaN       12051
# 835                   NaN          None               NaN       12051
# 977                   NaN          None               NaN       12051
# 1118                  NaN          None               NaN       12051
# 1259                  NaN          None               NaN       12051
# 1400                  NaN          None               NaN       12051
#
#                   program_name sector program_model overnight_service_type  \
# 128   Nellie's Women's Shelter  Women     Emergency                Shelter
# 269   Nellie's Women's Shelter  Women     Emergency                Shelter
# 410   Nellie's Women's Shelter  Women     Emergency                Shelter
# 551   Nellie's Women's Shelter  Women     Emergency                Shelter
# 693   Nellie's Women's Shelter  Women     Emergency                Shelter
# 835   Nellie's Women's Shelter  Women     Emergency                Shelter
# 977   Nellie's Women's Shelter  Women     Emergency                Shelter
# 1118  Nellie's Women's Shelter  Women     Emergency                Shelter
# 1259  Nellie's Women's Shelter  Women     Emergency                Shelter
# 1400  Nellie's Women's Shelter  Women     Emergency                Shelter
#
#                                     program_area  service_user_count  \
# 128   Base Shelter and Overnight Services System                  10
# 269   Base Shelter and Overnight Services System                  10
# 410   Base Shelter and Overnight Services System                  10
# 551   Base Shelter and Overnight Services System                  10
# 693   Base Shelter and Overnight Services System                  10
# 835   Base Shelter and Overnight Services System                  10
# 977   Base Shelter and Overnight Services System                  10
# 1118  Base Shelter and Overnight Services System                  10
# 1259  Base Shelter and Overnight Services System                  10
# 1400  Base Shelter and Overnight Services System                  10
#
#            capacity_type  capacity_actual_bed  capacity_funding_bed  \
# 128   Bed Based Capacity                 10.0                  10.0
# 269   Bed Based Capacity                 10.0                  10.0
# 410   Bed Based Capacity                 10.0                  10.0
# 551   Bed Based Capacity                 10.0                  10.0
# 693   Bed Based Capacity                 10.0                  10.0
# 835   Bed Based Capacity                 10.0                  10.0
# 977   Bed Based Capacity                 10.0                  10.0
# 1118  Bed Based Capacity                 10.0                  10.0
# 1259  Bed Based Capacity                 10.0                  10.0
# 1400  Bed Based Capacity                 10.0                  10.0
#
#       occupied_beds  unoccupied_beds  unavailable_beds  capacity_actual_room  \
# 128            10.0              0.0               0.0                   NaN
# 269            10.0              0.0               0.0                   NaN
# 410            10.0              0.0               0.0                   NaN
# 551            10.0              0.0               0.0                   NaN
# 693            10.0              0.0               0.0                   NaN
# 835            10.0              0.0               0.0                   NaN
# 977            10.0              0.0               0.0                   NaN
# 1118           10.0              0.0               0.0                   NaN
# 1259           10.0              0.0               0.0                   NaN
# 1400           10.0              0.0               0.0                   NaN
#
#       capacity_funding_room  occupied_rooms  unoccupied_rooms  \
# 128                     NaN             NaN               NaN
# 269                     NaN             NaN               NaN
# 410                     NaN             NaN               NaN
# 551                     NaN             NaN               NaN
# 693                     NaN             NaN               NaN
# 835                     NaN             NaN               NaN
# 977                     NaN             NaN               NaN
# 1118                    NaN             NaN               NaN
# 1259                    NaN             NaN               NaN
# 1400                    NaN             NaN               NaN
#
#       unavailable_rooms  occupancy_rate_beds  occupancy_rate_rooms
# 128                 NaN                100.0                   NaN
# 269                 NaN                100.0                   NaN
# 410                 NaN                100.0                   NaN
# 551                 NaN                100.0                   NaN
# 693                 NaN                100.0                   NaN
# 835                 NaN                100.0                   NaN
# 977                 NaN                100.0                   NaN
# 1118                NaN                100.0                   NaN
# 1259                NaN                100.0                   NaN
# 1400                NaN                100.0                   NaN

# %%
display(shelter_df[shelter_df['shelter_id'] == 27].shape)
# Out:
# (1185, 32)

# %%
shelter_df[(shelter_df['shelter_id'] == 27) & 
            ((shelter_df['location_address'].notnull()) | 
             (shelter_df['location_postal_code'].notnull()) | 
             (shelter_df['location_city'].notnull()) | 
             (shelter_df['location_province'].notnull()))].sum().sum()
# Out:
# 0.0

# %% [markdown]
# > they are all from shelter_id # 27 --> same place
# > so I looked up the shelter - it's in Toronto

# %%
display(shelter_df[shelter_df['shelter_id'] == 27].head(1))
# Out:
#      _id      date  organization_id     organization_name  shelter_id  \
# 128  129  01.01.21               16  Women's Hostels Inc.          27
#
#     shelter_group  location_id             location_name location_address  \
# 128      Nellie's       1035.0  Nellie's Women's Shelter              NaN
#
#     location_postal_code location_city location_province  program_id  \
# 128                  NaN          None               NaN       12051
#
#                  program_name sector program_model overnight_service_type  \
# 128  Nellie's Women's Shelter  Women     Emergency                Shelter
#
#                                    program_area  service_user_count  \
# 128  Base Shelter and Overnight Services System                  10
#
#           capacity_type  capacity_actual_bed  capacity_funding_bed  \
# 128  Bed Based Capacity                 10.0                  10.0
#
#      occupied_beds  unoccupied_beds  unavailable_beds  capacity_actual_room  \
# 128           10.0              0.0               0.0                   NaN
#
#      capacity_funding_room  occupied_rooms  unoccupied_rooms  \
# 128                    NaN             NaN               NaN
#
#      unavailable_rooms  occupancy_rate_beds  occupancy_rate_rooms
# 128                NaN                100.0                   NaN

# %%
shelter_df.loc[shelter_df['shelter_id'] == 27, 'location_city'] = 'Toronto'

# %%
shelter_df['location_city'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### drop columns that are irrelevant
# > - cross checked with the meaning of the columns in [Data Processing](../../data/Data_Processing.md)

# %%
shelter_df.head(10)
# Out:
#    _id      date  organization_id                        organization_name  \
# 0    1  01.01.21               24                 COSTI Immigrant Services
# 1    2  01.01.21               24                 COSTI Immigrant Services
# 2    3  01.01.21               24                 COSTI Immigrant Services
# 3    4  01.01.21               24                 COSTI Immigrant Services
# 4    5  01.01.21               24                 COSTI Immigrant Services
# 5    6  01.01.21               24                 COSTI Immigrant Services
# 6    7  01.01.21               24                 COSTI Immigrant Services
# 7    8  01.01.21               24                 COSTI Immigrant Services
# 8    9  01.01.21               14  Christie Ossington Neighbourhood Centre
# 9   10  01.01.21               14  Christie Ossington Neighbourhood Centre
#
#    shelter_id                    shelter_group  location_id  \
# 0          40           COSTI Reception Centre       1103.0
# 1          40           COSTI Reception Centre       1103.0
# 2          40           COSTI Reception Centre       1103.0
# 3          40           COSTI Reception Centre       1103.0
# 4          40           COSTI Reception Centre       1103.0
# 5          40           COSTI Reception Centre       1051.0
# 6          40           COSTI Reception Centre       1114.0
# 7          40           COSTI Reception Centre       1114.0
# 8          22  Christie Ossington Men's Hostel       1160.0
# 9          22  Christie Ossington Men's Hostel       1172.0
#
#                               location_name     location_address  \
# 0  COSTI/City North York West Hotel Program      1677 Wilson Ave
# 1  COSTI/City North York West Hotel Program      1677 Wilson Ave
# 2  COSTI/City North York West Hotel Program      1677 Wilson Ave
# 3  COSTI/City North York West Hotel Program      1677 Wilson Ave
# 4  COSTI/City North York West Hotel Program      1677 Wilson Ave
# 5                    COSTI Reception Centre    100 Lippincott St
# 6                COSTI Uptown Hotel Program      55 Hallcrown Pl
# 7                COSTI Uptown Hotel Program      55 Hallcrown Pl
# 8              CONC Etobicoke Hotel Program     445 Rexdale Blvd
# 9               CONC West End Hotel Program  14 Roncesvalles Ave
#
#   location_postal_code location_city location_province  program_id  \
# 0              M3L 1A5   North York                 ON       15371
# 1              M3L 1A5   North York                 ON       16211
# 2              M3L 1A5   North York                 ON       16192
# 3              M3L 1A5   North York                 ON       16191
# 4              M3L 1A5   North York                 ON       16193
# 5              M5S 2P1   North York                 ON       12251
# 6              M2J 4R1   North York                 ON       15372
# 7              M2J 4R1   North York                 ON       13751
# 8              M9W 6P8     Etobicoke                ON       16111
# 9              M6R 2K3     Etobicoke                ON       15711
#
#                                         program_name       sector  \
# 0       COSTI North York West Hotel - Family Program     Families
# 1      COSTI North York West Hotel - Seniors Program  Mixed Adult
# 2          COSTI North York West Hotel Program - Men          Men
# 3  COSTI North York West Hotel Program - Mixed Adult  Mixed Adult
# 4        COSTI North York West Hotel Program - Women        Women
# 5                COSTI Reception Centre CITY Program  Mixed Adult
# 6       COSTI Uptown Hotel COVID-19 - Family Program     Families
# 7                  COSTI Uptown Hotel Family Program     Families
# 8         CONC Etobicoke Hotel Program - Mixed Adult  Mixed Adult
# 9                           CONC Men's Hotel Program          Men
#
#   program_model overnight_service_type  \
# 0     Emergency    Motel/Hotel Shelter
# 1     Emergency    Motel/Hotel Shelter
# 2     Emergency    Motel/Hotel Shelter
# 3     Emergency    Motel/Hotel Shelter
# 4     Emergency    Motel/Hotel Shelter
# 5     Emergency                Shelter
# 6     Emergency    Motel/Hotel Shelter
# 7     Emergency    Motel/Hotel Shelter
# 8     Emergency    Motel/Hotel Shelter
# 9     Emergency    Motel/Hotel Shelter
#
#                                  program_area  service_user_count  \
# 0                           COVID-19 Response                  74
# 1                           COVID-19 Response                   3
# 2                           COVID-19 Response                  24
# 3                           COVID-19 Response                  25
# 4                           COVID-19 Response                  13
# 5  Base Shelter and Overnight Services System                   6
# 6                           COVID-19 Response                 120
# 7                  Temporary Refugee Response                 130
# 8                           COVID-19 Response                 153
# 9                           COVID-19 Response                  40
#
#          capacity_type  capacity_actual_bed  capacity_funding_bed  \
# 0  Room Based Capacity                  NaN                   NaN
# 1  Room Based Capacity                  NaN                   NaN
# 2  Room Based Capacity                  NaN                   NaN
# 3  Room Based Capacity                  NaN                   NaN
# 4  Room Based Capacity                  NaN                   NaN
# 5   Bed Based Capacity                  8.0                   8.0
# 6  Room Based Capacity                  NaN                   NaN
# 7  Room Based Capacity                  NaN                   NaN
# 8  Room Based Capacity                  NaN                   NaN
# 9  Room Based Capacity                  NaN                   NaN
#
#    occupied_beds  unoccupied_beds  unavailable_beds  capacity_actual_room  \
# 0            NaN              NaN               NaN                  29.0
# 1            NaN              NaN               NaN                   3.0
# 2            NaN              NaN               NaN                  28.0
# 3            NaN              NaN               NaN                  17.0
# 4            NaN              NaN               NaN                  14.0
# 5            6.0              2.0               0.0                   NaN
# 6            NaN              NaN               NaN                  46.0
# 7            NaN              NaN               NaN                  46.0
# 8            NaN              NaN               NaN                 145.0
# 9            NaN              NaN               NaN                  41.0
#
#    capacity_funding_room  occupied_rooms  unoccupied_rooms  unavailable_rooms  \
# 0                   58.0            26.0               3.0               29.0
# 1                    0.0             3.0               0.0                0.0
# 2                    0.0            23.0               5.0                0.0
# 3                    0.0            17.0               0.0                0.0
# 4                    0.0            13.0               1.0                0.0
# 5                    NaN             NaN               NaN                NaN
# 6                   25.0            44.0               2.0                0.0
# 7                  100.0            44.0               2.0               54.0
# 8                    0.0           145.0               0.0                0.0
# 9                    0.0            40.0               1.0                0.0
#
#    occupancy_rate_beds  occupancy_rate_rooms
# 0                  NaN                 89.66
# 1                  NaN                100.00
# 2                  NaN                 82.14
# 3                  NaN                100.00
# 4                  NaN                 92.86
# 5                 75.0                   NaN
# 6                  NaN                 95.65
# 7                  NaN                 95.65
# 8                  NaN                100.00
# 9                  NaN                 97.56

# %%
drop_columns = ['_id', 'organization_id', 'organization_name', 'shelter_id',
       'shelter_group', 'location_id', 'location_name', 'location_address',
       'location_postal_code', 'location_province',
       'program_id', 'program_name', 'program_model',
       'program_area', 'service_user_count', 'capacity_actual_bed', 'capacity_funding_bed',
       'capacity_actual_room', 'capacity_funding_room','unavailable_beds', 'unavailable_rooms']

# %%
shelter_df.drop(columns=drop_columns, inplace=True)

# %%
shelter_df
# Out:
#             date location_city       sector overnight_service_type  \
# 0       01.01.21   North York      Families    Motel/Hotel Shelter
# 1       01.01.21   North York   Mixed Adult    Motel/Hotel Shelter
# 2       01.01.21   North York           Men    Motel/Hotel Shelter
# 3       01.01.21   North York   Mixed Adult    Motel/Hotel Shelter
# 4       01.01.21   North York         Women    Motel/Hotel Shelter
# ...          ...           ...          ...                    ...
# 161036  31.03.24       Toronto        Youth                Shelter
# 161037  31.03.24       Toronto        Women                Shelter
# 161038  31.03.24       Toronto        Youth                Shelter
# 161039  31.03.24     Etobicoke        Youth                Shelter
# 161041  31.03.24   Scarborough        Youth                Shelter
#
#               capacity_type  occupied_beds  unoccupied_beds  occupied_rooms  \
# 0       Room Based Capacity            NaN              NaN            26.0
# 1       Room Based Capacity            NaN              NaN             3.0
# 2       Room Based Capacity            NaN              NaN            23.0
# 3       Room Based Capacity            NaN              NaN            17.0
# 4       Room Based Capacity            NaN              NaN            13.0
# ...                     ...            ...              ...             ...
# 161036   Bed Based Capacity           31.0              0.0             NaN
# 161037   Bed Based Capacity           28.0              0.0             NaN
# 161038   Bed Based Capacity           27.0              0.0             NaN
# 161039   Bed Based Capacity           33.0              0.0             NaN
# 161041   Bed Based Capacity           10.0              0.0             NaN
#
#         unoccupied_rooms  occupancy_rate_beds  occupancy_rate_rooms
# 0                    3.0                  NaN                 89.66
# 1                    0.0                  NaN                100.00
# 2                    5.0                  NaN                 82.14
# 3                    0.0                  NaN                100.00
# 4                    1.0                  NaN                 92.86
# ...                  ...                  ...                   ...
# 161036               NaN                100.0                   NaN
# 161037               NaN                100.0                   NaN
# 161038               NaN                100.0                   NaN
# 161039               NaN                100.0                   NaN
# 161041               NaN                100.0                   NaN
#
# [128349 rows x 11 columns]

# %% [markdown]
# > dropping occupancy_rate_beds and occupancy_rate_rooms as well, as we can recalculate them and I need to group by other factors frist

# %%
shelter_df.drop(columns=['occupancy_rate_beds', 'occupancy_rate_rooms'], inplace=True)

# %% [markdown]
# #### clean capacity_type

# %%
shelter_df['capacity_type'] = shelter_df['capacity_type'].map(lambda x: x.split(' ')[0] if isinstance(x, str) else x)

# %% [markdown]
# #### turn room and beds into general unit

# %%
shelter_df['taken_units'] = shelter_df.apply(lambda row: row['occupied_rooms'] if row['capacity_type'] == 'Room' else row['occupied_beds'], axis=1)
shelter_df['free_units'] = shelter_df.apply(lambda row: row['unoccupied_rooms'] if row['capacity_type'] == 'Room' else row['unoccupied_beds'], axis=1)
shelter_df.drop(columns=['occupied_beds', 'unoccupied_beds', 'occupied_rooms', 'unoccupied_rooms'], inplace=True)

# %% [markdown]
# #### get the capacity rate (this is my target for the model)

# %%
shelter_df['capacity_rate'] = shelter_df['taken_units'] / (shelter_df['taken_units'] + shelter_df['free_units'])

# %% [markdown]
# #### get the availability rate, not for model but for eda

# %%
shelter_df['availability'] = shelter_df['free_units'] / (shelter_df['taken_units'] + shelter_df['free_units'])

# %% [markdown]
# #### check

# %%
display(shelter_df.head(10))
display(shelter_df.shape)
# Out:
#        date location_city       sector overnight_service_type capacity_type  \
# 0  01.01.21   North York      Families    Motel/Hotel Shelter          Room
# 1  01.01.21   North York   Mixed Adult    Motel/Hotel Shelter          Room
# 2  01.01.21   North York           Men    Motel/Hotel Shelter          Room
# 3  01.01.21   North York   Mixed Adult    Motel/Hotel Shelter          Room
# 4  01.01.21   North York         Women    Motel/Hotel Shelter          Room
# 5  01.01.21   North York   Mixed Adult                Shelter           Bed
# 6  01.01.21   North York      Families    Motel/Hotel Shelter          Room
# 7  01.01.21   North York      Families    Motel/Hotel Shelter          Room
# 8  01.01.21     Etobicoke  Mixed Adult    Motel/Hotel Shelter          Room
# 9  01.01.21     Etobicoke          Men    Motel/Hotel Shelter          Room
#
#    taken_units  free_units  capacity_rate  availability
# 0         26.0         3.0       0.896552      0.103448
# 1          3.0         0.0       1.000000      0.000000
# 2         23.0         5.0       0.821429      0.178571
# 3         17.0         0.0       1.000000      0.000000
# 4         13.0         1.0       0.928571      0.071429
# 5          6.0         2.0       0.750000      0.250000
# 6         44.0         2.0       0.956522      0.043478
# 7         44.0         2.0       0.956522      0.043478
# 8        145.0         0.0       1.000000      0.000000
# 9         40.0         1.0       0.975610      0.024390
# (128349, 9)

# %%
shelter_df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### validate function

# %%
test_df = preprocess_climate_data(['../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2021.csv',
        '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2022.csv',
        '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2023.csv',
        '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-Q1:2024.csv'])
df_equality(test_df, shelter_df)
# Out:
# True

# %% [markdown]
# #### write to csv

# %%
test_df.to_csv('../../data/processed/shelter.csv', index=False)
