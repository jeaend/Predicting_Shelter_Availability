# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../'))
sys.path.insert(1, module_path + "/utils")

import pandas as pd
from data_processing import preprocess_climate_data, preprocess_shelter_data, df_equality

# %% [markdown]
# #### data retrieval from perviously saved csv's

# %%
# read the CSV files
climate_df_csv = pd.read_csv("../../data/processed/climate.csv")
shelter_df_csv = pd.read_csv("../../data/processed/shelter.csv")

# merge the dataframes based on the 'date' column, left join
merged_df_csv = pd.merge(shelter_df_csv, climate_df_csv, on='date', how='left')

# %% [markdown]
# ##### check df

# %%
merged_df_csv.isna().sum().sum()
# Out:
# 0

# %%
merged_df_csv
# Out:
#             date location_city       sector overnight_service_type  \
# 0       01.01.21   North York      Families    Motel/Hotel Shelter
# 1       01.01.21   North York   Mixed Adult    Motel/Hotel Shelter
# 2       01.01.21   North York           Men    Motel/Hotel Shelter
# 3       01.01.21   North York   Mixed Adult    Motel/Hotel Shelter
# 4       01.01.21   North York         Women    Motel/Hotel Shelter
# ...          ...           ...          ...                    ...
# 128344  31.03.24       Toronto        Youth                Shelter
# 128345  31.03.24       Toronto        Women                Shelter
# 128346  31.03.24       Toronto        Youth                Shelter
# 128347  31.03.24     Etobicoke        Youth                Shelter
# 128348  31.03.24   Scarborough        Youth                Shelter
#
#        capacity_type  taken_units  free_units  capacity_rate  availability  \
# 0               Room         26.0         3.0       0.896552      0.103448
# 1               Room          3.0         0.0       1.000000      0.000000
# 2               Room         23.0         5.0       0.821429      0.178571
# 3               Room         17.0         0.0       1.000000      0.000000
# 4               Room         13.0         1.0       0.928571      0.071429
# ...              ...          ...         ...            ...           ...
# 128344           Bed         31.0         0.0       1.000000      0.000000
# 128345           Bed         28.0         0.0       1.000000      0.000000
# 128346           Bed         27.0         0.0       1.000000      0.000000
# 128347           Bed         33.0         0.0       1.000000      0.000000
# 128348           Bed         10.0         0.0       1.000000      0.000000
#
#         min_temperature  total_precipitation  mean_temperature  \
# 0                  -1.0                  6.8               0.7
# 1                  -1.0                  6.8               0.7
# 2                  -1.0                  6.8               0.7
# 3                  -1.0                  6.8               0.7
# 4                  -1.0                  6.8               0.7
# ...                 ...                  ...               ...
# 128344              2.0                  0.0               5.3
# 128345              2.0                  0.0               5.3
# 128346              2.0                  0.0               5.3
# 128347              2.0                  0.0               5.3
# 128348              2.0                  0.0               5.3
#
#         max_temperature  snow_on_ground
# 0                   2.5             0.0
# 1                   2.5             0.0
# 2                   2.5             0.0
# 3                   2.5             0.0
# 4                   2.5             0.0
# ...                 ...             ...
# 128344              8.6             0.0
# 128345              8.6             0.0
# 128346              8.6             0.0
# 128347              8.6             0.0
# 128348              8.6             0.0
#
# [128349 rows x 14 columns]

# %%
# Save the merged dataframe to a new CSV file
# merged_df_csv.to_csv("../../data/processed/shelter_climate.csv", index=False)

# %% [markdown]
# #### alternatively using the functions and merge directly wihtout using previously saved state

# %%
climate_url = '../../data/raw/climate/climate-toronto2021-Q1-2024.csv'
shelter_url = ['../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2021.csv',
        '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2022.csv',
        '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-2023.csv',
        '../../data/raw/shelter/daily-shelter-overnight-service-occupancy-capacity-Q1:2024.csv']

climate_df = preprocess_climate_data(climate_url)
shelter_df = preprocess_shelter_data(shelter_url)

climate_shelter = pd.merge(shelter_df, climate_df, on='date', how='left')

# %% [markdown]
# ##### check df

# %%
climate_shelter.isna().sum().sum()
climate_shelter.columns == merged_df_csv.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %% [markdown]
# #### save to csv

# %%
# Save the merged dataframe to a new CSV file
climate_shelter.to_csv("../../data/processed/shelter_climate.csv", index=False)
